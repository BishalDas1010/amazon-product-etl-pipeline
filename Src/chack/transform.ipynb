# %%
print("spark")
# Out:
# spark

# %%
from pyspark.sql import SparkSession
spark = (
    SparkSession.builder\
    .appName("Readcsv")
    .master("locals[*]").getOrCreate()
)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# /tmp/ipython-input-259/3575648757.py in <cell line: 0>()
#       3     SparkSession.builder\
#       4     .appName("Readcsv")
# ----> 5     .master("locals[*]").getOrCreate()
#       6 )
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/session.py in getOrCreate(self)
#     554                         sparkConf.set(key, value)
#     555                     # This SparkContext may be an existing one.
# --> 556                     sc = SparkContext.getOrCreate(sparkConf)
#     557                     # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     558                     # by all sessions.
#
# /usr/local/lib/python3.12/dist-packages/pyspark/core/context.py in getOrCreate(cls, conf)
#     521         with SparkContext._lock:
#     522             if SparkContext._active_spark_context is None:
# ...

# %%
df = (
    spark.read
    .format("csv")
    .option("header", "true")        # First row as column names
    .option("inferSchema", "true")   # Automatically detect data types
    .load("/home/bishaldas/data/sample.csv")
)
